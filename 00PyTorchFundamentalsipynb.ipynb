# %% [markdown]
# <a href="https://colab.research.google.com/github/khinthandarkyaw98/50projects50days/blob/master/00PyTorchFundamentalsipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***23 Feb 2024***
#
# ***Coral***
#
# ***00.PyTorch Fundmentals***

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu121'

# %% [markdown]
# ###Scalar Value

# %%
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.dtype
# Out:
# torch.int64

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %% [markdown]
# ### Vector

# %%
vector = torch.tensor([7, 7])
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %% [markdown]
# ### Matrix

# %%
MATRIX = torch.tensor([[7, 8],
                       [9, 10]])

MATRIX
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
MATRIX.shape
# Out:
# torch.Size([2, 2])

# %%
MATRIX.ndim
# Out:
# 2

# %% [markdown]
# ### Tensor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
TENSOR = torch.tensor([[[1, 2, 3],
                        [3, 6, 9],
                        [2, 4, 5]]])
TENSOR
# Out:
# tensor([[[1, 2, 3],
#          [3, 6, 9],
#          [2, 4, 5]]])

# %%
TENSOR.ndim
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
TENSOR.shape
# Out:
# torch.Size([1, 3, 3])

# %% [markdown]
# ### Random tensors

# %% [markdown]
# Start with random numbers -> look at data -> update random numbers -> look at data -> update random numbers...

# %%
random_tensor = torch.rand(size=(3, 4))
random_tensor, random_tensor.dtype
# Out:
# (tensor([[0.2692, 0.1421, 0.0751, 0.3729],
#          [0.3948, 0.0009, 0.2993, 0.5044],
#          [0.0850, 0.3864, 0.1200, 0.1731]]),
#  torch.float32)
